# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**                      Pedro Orlandelli Alves Aranha
#
# **Turma:**                              2bti
#
#
# **Tema Escolhido:**                      montar cardapios escolares

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class Alimento_Pedro:
    def __init__(self, nome, categoria, calorias):
        self.nome = nome
        self.categoria = categoria
        self.calorias = calorias

    def exibir_dados_Pedro(self):
        print(f"Nome: {self.nome}")
        print(f"Categoria: {self.categoria}")
        print(f"Calorias: {self.calorias} kcal")

# Criando objetos da classe principal
alimento1_Pedro = Alimento_Pedro("Arroz", "Carboidrato", 130)
alimento2_Pedro = Alimento_Pedro("Frango grelhado", "Proteína", 165)

# Exibindo os dados dos objetos
print("📌 Alimento 1:")
alimento1_Pedro.exibir_dados_Pedro()

print("\n📌 Alimento 2:")
alimento2_Pedro.exibir_dados_Pedro()
# Out:
# 📌 Alimento 1:
# Nome: Arroz
# Categoria: Carboidrato
# Calorias: 130 kcal
#
# 📌 Alimento 2:
# Nome: Frango grelhado
# Categoria: Proteína
# Calorias: 165 kcal

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class Alimento_Pedro:
    def __init__(self, nome, categoria, calorias):
        self.nome = nome
        self.categoria = categoria
        self.calorias = calorias

    def exibir_dados_Pedro(self):
        print(f"Nome: {self.nome}")
        print(f"Categoria: {self.categoria}")
        print(f"Calorias: {self.calorias} kcal")

    def atualizar_calorias_Pedro(self, nova_caloria):
        self.calorias = nova_caloria
        print(f"Calorias do alimento '{self.nome}' atualizadas para {self.calorias} kcal")

    def verificar_categoria_Pedro(self):
        print(f"O alimento '{self.nome}' pertence à categoria '{self.categoria}'.")

class AlimentoRestrito_Pedro(Alimento_Pedro):
    def __init__(self, nome, categoria, calorias, restricoes):
        super().__init__(nome, categoria, calorias)
        self.restricoes = restricoes

    def exibir_restricoes_Pedro(self):
        print(f"O alimento '{self.nome}' possui as seguintes restrições: {', '.join(self.restricoes)}")

alimento1_Pedro = Alimento_Pedro("Arroz", "Carboidrato", 130)
alimento2_Pedro = Alimento_Pedro("Frango grelhado", "Proteína", 165)
alimento3_Pedro = Alimento_Pedro("Banana", "Fruta", 90)
alimento4_Pedro = AlimentoRestrito_Pedro("Leite", "Laticínio", 120, ["lactose"])

print("📌 Alimento 1:")
alimento1_Pedro.exibir_dados_Pedro()
print("\n📌 Alimento 2:")
alimento2_Pedro.exibir_dados_Pedro()

print("\n📌 Alimento 3:")
alimento3_Pedro.exibir_dados_Pedro()
alimento3_Pedro.atualizar_calorias_Pedro(95)
alimento3_Pedro.verificar_categoria_Pedro()

print("\n📌 Alimento 4:")
alimento4_Pedro.exibir_dados_Pedro()
alimento4_Pedro.exibir_restricoes_Pedro()
# Out:
# 📌 Alimento 1:
# Nome: Arroz
# Categoria: Carboidrato
# Calorias: 130 kcal
#
# 📌 Alimento 2:
# Nome: Frango grelhado
# Categoria: Proteína
# Calorias: 165 kcal
#
# 📌 Alimento 3:
# Nome: Banana
# Categoria: Fruta
# Calorias: 90 kcal
# Calorias do alimento 'Banana' atualizadas para 95 kcal
# O alimento 'Banana' pertence à categoria 'Fruta'.
#
# 📌 Alimento 4:
# Nome: Leite
# Categoria: Laticínio
# Calorias: 120 kcal
# O alimento 'Leite' possui as seguintes restrições: lactose

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
class CardapioEscolar:
    def __init__(self, dia, itens, calorias_totais):
        self.dia = dia
        self.itens = itens  # Lista com os itens do cardápio
        self.__calorias_totais = calorias_totais  # Atributo privado

    # Getter
    def get_calorias_totais(self):
        return self.__calorias_totais

    # Setter
    def set_calorias_totais(self, novas_calorias):
        if novas_calorias >= 0:
            self.__calorias_totais = novas_calorias
        else:
            print("Erro: As calorias não podem ser negativas.")

    # Método com lógica interna
    def verificar_cardapio_saudavel(self):
        if self.__calorias_totais <= 600:
            return "Cardápio saudável."
        else:
            return "Cardápio com muitas calorias. Reavaliar."

    def exibir_cardapio(self):
        print(f"Dia: {self.dia}")
        print("Itens do cardápio:")
        for item in self.itens:
            print(f"- {item}")
        print(f"Calorias totais: {self.__calorias_totais}")
        print(self.verificar_cardapio_saudavel())

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# Criação da tabela no banco de dados
criar_tabela()

# Criando cardápios para inserção
cardapio_almoco = CardapioAlmoco(
    dia="Segunda-feira",
    itens=["Arroz", "Feijão", "Frango grelhado", "Salada", "Suco natural"],
    calorias_totais=550
)

cardapio_lanche = CardapioLanche(
    dia="Segunda-feira",
    itens=["Biscoito", "Suco de laranja"],
    calorias_totais=250
)

# Inserindo cardápios no banco de dados
inserir_cardapio(cardapio_almoco.tipo_cardapio(), cardapio_almoco.dia, cardapio_almoco.itens, cardapio_almoco.get_calorias_totais())
inserir_cardapio(cardapio_lanche.tipo_cardapio(), cardapio_lanche.dia, cardapio_lanche.itens, cardapio_lanche.get_calorias_totais())

# Exibindo todos os cardápios inseridos no banco de dados
print("\nCardápios cadastrados no banco de dados:")
exibir_cardapios()

# Excluindo um cardápio (exemplo: o cardápio de ID 1)
excluir_cardapio(1)

# Exibindo os cardápios após exclusão
print("\nCardápios após exclusão:")
exibir_cardapios()
# Out:
# Cardápios cadastrados no banco de dados:
# ID: 2, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250
# ID: 3, Tipo: Cardápio de Almoço, Dia: Segunda-feira, Itens: Arroz, Feijão, Frango grelhado, Salada, Suco natural, Calorias: 550
# ID: 4, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250
# ID: 5, Tipo: Cardápio de Almoço, Dia: Segunda-feira, Itens: Arroz, Feijão, Frango grelhado, Salada, Suco natural, Calorias: 550
# ID: 6, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250
#
# Cardápios após exclusão:
# ID: 2, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250
# ID: 3, Tipo: Cardápio de Almoço, Dia: Segunda-feira, Itens: Arroz, Feijão, Frango grelhado, Salada, Suco natural, Calorias: 550
# ID: 4, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250
# ID: 5, Tipo: Cardápio de Almoço, Dia: Segunda-feira, Itens: Arroz, Feijão, Frango grelhado, Salada, Suco natural, Calorias: 550
# ID: 6, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import sqlite3  # IMPORTAÇÃO DO SQLITE3 (corrigido)

# ==============================
# Parte 1 - 3: Encapsulamento, Abstração e Polimorfismo
# ==============================

# Classe base para cardápio escolar
class CardapioEscolar:
    def __init__(self, dia, itens, calorias_totais):
        self.dia = dia  # Dia da semana (Segunda-feira, Terça-feira, etc.)
        self.itens = itens  # Lista de itens do cardápio
        self.__calorias_totais = calorias_totais  # Atributo privado para calorias

    # Getter para o atributo privado __calorias_totais
    def get_calorias_totais(self):
        return self.__calorias_totais

    # Setter para o atributo privado __calorias_totais (com verificação)
    def set_calorias_totais(self, novas_calorias):
        if novas_calorias >= 0:
            self.__calorias_totais = novas_calorias
        else:
            print("Erro: As calorias não podem ser negativas.")

    # Exibir o cardápio completo (dia, itens, calorias)
    def exibir_cardapio(self):
        print(f"Dia: {self.dia}")
        print("Itens do cardápio:")
        for item in self.itens:
            print(f"- {item}")
        print(f"Calorias totais: {self.__calorias_totais}")

    # Método polimórfico (será sobrescrito nas subclasses)
    def tipo_cardapio(self):
        pass

# Subclasse para Cardápio de Almoço
class CardapioAlmoco(CardapioEscolar):
    def tipo_cardapio(self):
        return "Cardápio de Almoço"

# Subclasse para Cardápio de Lanche
class CardapioLanche(CardapioEscolar):
    def tipo_cardapio(self):
        return "Cardápio de Lanche"

# ==============================
# Parte 4: Integração com Banco de Dados (SQLite)
# ==============================

# Função para conectar ao banco de dados SQLite
def conectar_db():
    return sqlite3.connect("cardapios.db")

# Função para criar a tabela 'cardapios' no banco de dados
def criar_tabela():
    conn = conectar_db()
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS cardapios (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            tipo TEXT,
            dia TEXT,
            itens TEXT,
            calorias_totais INTEGER
        )
    """)
    conn.commit()
    conn.close()

# Função para inserir um cardápio no banco de dados
def inserir_cardapio(tipo, dia, itens, calorias_totais):
    conn = conectar_db()
    cursor = conn.cursor()
    cursor.execute("""
        INSERT INTO cardapios (tipo, dia, itens, calorias_totais)
        VALUES (?, ?, ?, ?)
    """, (tipo, dia, ', '.join(itens), calorias_totais))
    conn.commit()
    conn.close()

# Função para consultar todos os cardápios no banco de dados
def consultar_cardapios():
    conn = conectar_db()
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM cardapios")
    cardapios = cursor.fetchall()
    conn.close()
    return cardapios

# Função para excluir um cardápio pelo seu ID
def excluir_cardapio(cardapio_id):
    conn = conectar_db()
    cursor = conn.cursor()
    cursor.execute("DELETE FROM cardapios WHERE id = ?", (cardapio_id,))
    conn.commit()
    conn.close()

# Função para exibir os cardápios cadastrados no banco de dados
def exibir_cardapios():
    cardapios = consultar_cardapios()
    if not cardapios:
        print("Nenhum cardápio cadastrado.")
    for cardapio in cardapios:
        print(f"ID: {cardapio[0]}, Tipo: {cardapio[1]}, Dia: {cardapio[2]}, Itens: {cardapio[3]}, Calorias: {cardapio[4]}")

# ==============================
# Parte 5: Testando o código e funcionalidades
# ==============================

# Criação da tabela no banco de dados
criar_tabela()

# Criando cardápios para inserção (utilizando as subclasses)
cardapio_almoco = CardapioAlmoco(
    dia="Segunda-feira",
    itens=["Arroz", "Feijão", "Frango grelhado", "Salada", "Suco natural"],
    calorias_totais=550
)

cardapio_lanche = CardapioLanche(
    dia="Segunda-feira",
    itens=["Biscoito", "Suco de laranja"],
    calorias_totais=250
)

# Inserindo cardápios no banco de dados teste
print("Inserindo cardápios no banco de dados...")
inserir_cardapio(cardapio_almoco.tipo_cardapio(), cardapio_almoco.dia, cardapio_almoco.itens, cardapio_almoco.get_calorias_totais())
inserir_cardapio(cardapio_lanche.tipo_cardapio(), cardapio_lanche.dia, cardapio_lanche.itens, cardapio_lanche.get_calorias_totais())

# Exibindo todos os cardápios cadastrados no banco de dados
print("\nCardápios cadastrados no banco de dados:")
exibir_cardapios()

# Excluindo um cardápio (exemplo: o cardápio de ID 1)
print("\nExcluindo cardápio de ID 1...")
excluir_cardapio(1)

# Exibindo os cardápios após exclusão
print("\nCardápios após exclusão:")
exibir_cardapios()
# Out:
# Inserindo cardápios no banco de dados...
#
# Cardápios cadastrados no banco de dados:
# ID: 2, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250
# ID: 3, Tipo: Cardápio de Almoço, Dia: Segunda-feira, Itens: Arroz, Feijão, Frango grelhado, Salada, Suco natural, Calorias: 550
# ID: 4, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250
# ID: 5, Tipo: Cardápio de Almoço, Dia: Segunda-feira, Itens: Arroz, Feijão, Frango grelhado, Salada, Suco natural, Calorias: 550
# ID: 6, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250
# ID: 7, Tipo: Cardápio de Almoço, Dia: Segunda-feira, Itens: Arroz, Feijão, Frango grelhado, Salada, Suco natural, Calorias: 550
# ID: 8, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250
#
# Excluindo cardápio de ID 1...
#
# Cardápios após exclusão:
# ID: 2, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250
# ID: 3, Tipo: Cardápio de Almoço, Dia: Segunda-feira, Itens: Arroz, Feijão, Frango grelhado, Salada, Suco natural, Calorias: 550
# ID: 4, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250
# ID: 5, Tipo: Cardápio de Almoço, Dia: Segunda-feira, Itens: Arroz, Feijão, Frango grelhado, Salada, Suco natural, Calorias: 550
# ID: 6, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250
# ID: 7, Tipo: Cardápio de Almoço, Dia: Segunda-feira, Itens: Arroz, Feijão, Frango grelhado, Salada, Suco natural, Calorias: 550
# ID: 8, Tipo: Cardápio de Lanche, Dia: Segunda-feira, Itens: Biscoito, Suco de laranja, Calorias: 250
